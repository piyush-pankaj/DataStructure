# %% [markdown]
# 1. Lists and Arrays:
#    - Understanding the difference between lists and arrays.
#    - Operations like indexing, slicing, appending, and sorting.
#    - Time complexity analysis for common operations.
#
# 2. Dictionaries (Hash Maps):
#    - How dictionaries work and their key-value pair structure.
#    - Retrieval, insertion, and deletion of elements.
#    - Hashing functions and collisions.
#
# 3. Linked Lists:
#    - Singly linked lists and doubly linked lists.
#    - Insertion, deletion, and traversal.
#    - Advantages and disadvantages compared to arrays.
#
# 4. Stacks and Queues:
#    - LIFO (Last-In, First-Out) and FIFO (First-In, First-Out) principles.
#    - Implementing stacks and queues using arrays or linked lists.
#    - Use cases in data processing and algorithms.
#
# 5. Trees and Graphs:
#    - Binary trees, binary search trees (BST), and balanced BSTs.
#    - Graph representations (adjacency matrix and adjacency list).
#    - Tree traversal algorithms (pre-order, in-order, post-order).
#
# 6. Heaps:
#    - Min-heaps and max-heaps.
#    - Heap operations (insertion, deletion, heapify).
#    - Priority queues and their applications.
#
# 7. Hash Tables:
#    - Hashing techniques and collision resolution strategies.
#    - Efficient searching and insertion.
#    - Use cases in data indexing and caching.
#
# 8. Arrays of Structures vs. Structures of Arrays:
#    - Data layout considerations for optimizing memory access.
#    - When to use each data structure for specific data processing tasks.
#
# 9. Tries:
#    - Trie data structure for efficient string operations.
#    - Prefix matching and autocomplete applications.
#
# 10. Bloom Filters:
#     - Probabilistic data structure for membership testing.
#     - False positive and false negative rates.
#     - Applications in data deduplication and spell-checking.
#
# 11. Sparse Data Structures:
#     - Representing and handling sparse matrices and arrays.
#     - Compressed Sparse Row (CSR) and Compressed Sparse Column (CSC) formats.
#
# 12. Time Series Data Structures:
#     - Rolling windows and time-based indexing.
#     - Data structures for efficiently storing and analyzing time series data.
#
# 13. Data Structures for Text Processing:
#     - Trie structures for text indexing.
#     - Suffix trees and suffix arrays for pattern matching and searching.
#
# 14. Data Structures for Machine Learning:
#     - Sparse matrices and tensors for representing data.
#     - Data structures used in machine learning libraries (e.g., NumPy, TensorFlow).
